# %%
# organization_abm.py

import random
import networkx as nx
from mesa import Agent, Model
from mesa.time import SimultaneousActivation
from mesa.space import NetworkGrid
from mesa.datacollection import DataCollector
import matplotlib.pyplot as plt
import pandas as pd
import os

# ==========================
# 1. Define the Generative AI Agent
# ==========================

class GenerativeAI(Agent):
    """
    Generative AI agent that evolves over time by increasing its knowledge contribution.
    """
    def __init__(self, unique_id, model, initial_contribution=2.0, evolution_rate=0.05):
        super().__init__(unique_id, model)
        self.knowledge_contribution = initial_contribution
        self.evolution_rate = evolution_rate  # Rate at which AI evolves per step

    def step(self):
        # Evolve AI's knowledge contribution
        self.knowledge_contribution += self.evolution_rate

    def provide_information(self):
        return self.knowledge_contribution

# ==========================
# 2. Define the Employee Agent
# ==========================

class EmployeeAgent(Agent):
    """
    Employee agent with diverse roles, knowledge, AI attitudes, and behavioral dynamics.
    """
    def __init__(self, unique_id, model, role, expertise, ai_attitude):
        super().__init__(unique_id, model)
        self.role = role  # e.g., Manager, Staff, etc.
        self.expertise = expertise  # Expertise level (1-10)
        self.ai_attitude = ai_attitude  # 'positive', 'neutral', 'negative'
        self.knowledge = expertise  # Initialize knowledge base
        self.decay_rate = 0.01  # Knowledge decay rate per step
        self.ai_usefulness_threshold = 5.0  # Threshold to change attitude

    def step(self):
        # Debug: Log the current knowledge level before decay
        print(f"Agent {self.unique_id} stepping with knowledge before decay: {self.knowledge}")

        # Knowledge decay
        self.knowledge = max(self.knowledge - self.decay_rate, 0)

        # Debug: Log the current knowledge level after decay
        print(f"Agent {self.unique_id} knowledge after decay: {self.knowledge}")

        # Interact with social network
        social_neighbors = list(self.model.social_network.neighbors(self.unique_id))
        if social_neighbors:
            partner_id = random.choice(social_neighbors)
            partner = self.model.schedule.agents[partner_id]
            self.exchange_information(partner)
            # Debug: Log interaction with social partner
            print(f"Agent {self.unique_id} exchanged info with social partner {partner_id}")

        # Interact with organizational network if the agent exists in the network
        if self.unique_id in self.model.org_network:
            org_neighbors = list(self.model.org_network.neighbors(self.unique_id))
            if org_neighbors:
                org_partner_id = random.choice(org_neighbors)
                org_partner = self.model.schedule.agents[org_partner_id]
                self.exchange_information(org_partner)
                # Debug: Log interaction with organizational partner
                print(f"Agent {self.unique_id} exchanged info with org partner {org_partner_id}")

        # Interact with Generative AI
        self.interact_with_ai()
        # Debug: Log interaction with AI
        print(f"Agent {self.unique_id} interacted with AI. Current knowledge: {self.knowledge}")

        # Possibly evolve social network
        self.evolve_social_network()

        # Possibly change AI attitude based on knowledge
        self.update_ai_attitude()



    def exchange_information(self, partner):
        """
        Exchange information with another agent by averaging knowledge.
        """
        if isinstance(partner, EmployeeAgent):
            avg_knowledge = (self.knowledge + partner.knowledge) / 2
            self.knowledge = avg_knowledge
            partner.knowledge = avg_knowledge

    def interact_with_ai(self):
        """
        Interact with the AI agent based on AI attitude.
        """
        ai_agent = self.model.ai_agent
        if self.ai_attitude == 'positive':
            # AI augments knowledge
            self.knowledge += ai_agent.provide_information()
            self.model.ai_usage_count +=1
        elif self.ai_attitude == 'neutral':
            # AI provides minimal information
            self.knowledge += ai_agent.provide_information() * 0.5
            self.model.ai_usage_count +=0.5
        elif self.ai_attitude == 'negative':
            # Reluctant to use AI; minimal or no information
            self.knowledge += ai_agent.provide_information() * 0.2
            self.model.ai_usage_count +=0.2

    def evolve_social_network(self):
        """
        Dynamically evolve the social network by adding/removing connections.
        """
        add_prob = 0.01  # Probability to form a new connection
        remove_prob = 0.005  # Probability to remove an existing connection

        # Attempt to add a new social connection
        if random.random() < add_prob:
            possible_agents = set([agent.unique_id for agent in self.model.schedule.agents if isinstance(agent, EmployeeAgent)]) - set([self.unique_id]) - set(self.model.social_network.neighbors(self.unique_id))
            if possible_agents:
                new_neighbor = random.choice(list(possible_agents))
                self.model.social_network.add_edge(self.unique_id, new_neighbor)

        # Attempt to remove an existing social connection
        if random.random() < remove_prob and self.model.social_network.degree(self.unique_id) > 1:
            current_neighbors = list(self.model.social_network.neighbors(self.unique_id))
            if current_neighbors:
                remove_neighbor = random.choice(current_neighbors)
                self.model.social_network.remove_edge(self.unique_id, remove_neighbor)


    def update_ai_attitude(self):
        """
        Update AI attitude based on knowledge level.
        If knowledge exceeds a threshold, become more positive towards AI.
        If below, become more negative.
        """
        if self.knowledge > self.ai_usefulness_threshold and self.ai_attitude != 'positive':
            self.ai_attitude = 'positive'
        elif self.knowledge < self.ai_usefulness_threshold and self.ai_attitude != 'negative':
            self.ai_attitude = 'negative'
        # Else, remain neutral or current attitude

# ==========================
# 3. Define Network Creation Functions
# ==========================

def create_hierarchical_network(num_levels, span_of_control, num_employees):
    """
    Create a hierarchical organizational network, ensuring that the number of nodes
    matches or exceeds the number of employees.
    """
    G = nx.DiGraph()
    current_id = 0
    G.add_node(current_id)
    previous_level = [current_id]
    current_id += 1

    for level in range(1, num_levels):
        current_level = []
        for manager in previous_level:
            for _ in range(span_of_control):
                if current_id < num_employees:
                    G.add_node(current_id)
                    G.add_edge(manager, current_id)
                    current_level.append(current_id)
                    current_id += 1
        previous_level = current_level

    # If fewer nodes were created than num_employees, add extra nodes
    while len(G.nodes) < num_employees:
        G.add_node(current_id)
        current_id += 1

    return G


def create_onion_network(num_levels, span_of_control, num_employees):
    """
    Create an onion-like organizational network with inter-layer connections,
    ensuring that the number of nodes matches or exceeds the number of employees.
    """
    G = nx.DiGraph()
    current_id = 0
    G.add_node(current_id)
    previous_level = [current_id]
    current_id += 1

    for level in range(1, num_levels):
        current_level = []
        for manager in previous_level:
            for _ in range(span_of_control):
                if current_id < num_employees:
                    G.add_node(current_id)
                    G.add_edge(manager, current_id)
                    current_level.append(current_id)
                    current_id += 1
        # Add inter-layer connections (e.g., lateral connections)
        for node in current_level:
            if random.random() < 0.3 and previous_level:
                lateral = random.choice(previous_level)
                if lateral != node:
                    G.add_edge(node, lateral)
        previous_level = current_level

    # If fewer nodes were created than num_employees, add extra nodes
    while len(G.nodes) < num_employees:
        G.add_node(current_id)
        current_id += 1

    return G


def create_small_world_network(num_agents, k, p):
    """
    Create a small-world social network with enough nodes for all agents.
    """
    return nx.watts_strogatz_graph(num_agents, k, p)


def create_scale_free_network(num_agents, m):
    """
    Create a scale-free social network with enough nodes for all agents.
    """
    return nx.barabasi_albert_graph(num_agents, m)

# ==========================
# 4. Define the ABM Model
# ==========================

class OrganizationModel(Model):
    """
    Organization Model that simulates employees interacting within organizational and social networks,
    interacting with a generative AI agent, with dynamic networks, knowledge decay, AI evolution,
    diverse roles, and behavioral dynamics.
    """
    def __init__(self, 
                 num_employees=100, 
                 num_levels=4, 
                 span_of_control=4,
                 org_network_type='hierarchical',  # 'hierarchical' or 'onion'
                 social_network_type='small_world',  # 'small_world' or 'scale_free'
                 social_k=4, 
                 social_p=0.1, 
                 social_m=2,
                 ai_contribution=2.0,
                 ai_evolution_rate=0.05,
                 knowledge_decay_rate=0.01,
                 max_steps=100,
                 output_dir='output'):
        """
        Parameters:
            num_employees: Number of human agents
            num_levels: Number of hierarchical levels (for organizational networks)
            span_of_control: Number of direct reports per manager
            org_network_type: 'hierarchical' or 'onion'
            social_network_type: 'small_world' or 'scale_free'
            social_k: Parameter for social network (e.g., neighbors in small-world)
            social_p: Rewiring probability for small-world
            social_m: Parameter for scale-free network (number of edges to attach)
            ai_contribution: Initial AI's knowledge contribution per interaction
            ai_evolution_rate: Rate at which AI's knowledge contribution evolves per step
            knowledge_decay_rate: Rate at which agents' knowledge decays per step
            max_steps: Number of steps to run the simulation
            output_dir: Directory to save output data
        """
        self.num_employees = num_employees
        self.num_agents = num_employees
        self.schedule = SimultaneousActivation(self)
        self.running = True
        self.max_steps = max_steps
        self.current_step = 0

        # Create Organizational Network
        if org_network_type == 'hierarchical':
            self.org_network = create_hierarchical_network(num_levels, span_of_control, num_employees)
        elif org_network_type == 'onion':
            self.org_network = create_onion_network(num_levels, span_of_control, num_employees)
        else:
            raise ValueError("Unsupported organizational network type. Choose 'hierarchical' or 'onion'.")

        # Create Social Interaction Network
        total_agents = num_employees +1  # +1 for AI agent
        if social_network_type == 'small_world':
            self.social_network = create_small_world_network(total_agents, social_k, social_p)
        elif social_network_type == 'scale_free':
            self.social_network = create_scale_free_network(total_agents, social_m)
        else:
            raise ValueError("Unsupported social network type. Choose 'small_world' or 'scale_free'.")

        # Initialize Generative AI Agent
        ai_unique_id = num_employees  # Assign last ID to AI
        self.ai_agent = GenerativeAI(ai_unique_id, self, initial_contribution=ai_contribution, evolution_rate=ai_evolution_rate)
        self.schedule.add(self.ai_agent)

        # Initialize NetworkGrid with Social Network
        self.grid = NetworkGrid(self.social_network)

        # Initialize Agents
        for i in range(num_employees):
            role = self.assign_role(i)
            expertise = random.uniform(1, 10)
            ai_attitude = self.assign_ai_attitude()
            agent = EmployeeAgent(i, self, role, expertise, ai_attitude)
            agent.decay_rate = knowledge_decay_rate  # Set knowledge decay rate
            self.schedule.add(agent)
            self.grid.place_agent(agent, i)  # Place based on social network node

        # Place AI agent in the last node
        self.grid.place_agent(self.ai_agent, ai_unique_id)

        # Initialize AI usage count for utilization metrics
        self.ai_usage_count = 0.0

        # Data Collector
        self.datacollector = DataCollector(
            model_reporters={
                "Average Knowledge": self.compute_average_knowledge,
                "Knowledge Std Dev": self.compute_knowledge_std_dev,
                "AI Utilization": self.compute_ai_utilization,
                "Positive Attitudes": lambda m: m.count_ai_attitudes('positive'),
                "Neutral Attitudes": lambda m: m.count_ai_attitudes('neutral'),
                "Negative Attitudes": lambda m: m.count_ai_attitudes('negative'),
                "AI Contribution": self.get_ai_contribution
            }
        )

        # Prepare output directory
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        self.output_dir = output_dir

    def assign_role(self, agent_id):
        """
        Assign role based on hierarchical level in organizational network.
        Managers have higher hierarchical levels, Staff have lower.
        """
        # Determine the hierarchical level of the agent
        level = self.get_agent_level(agent_id)
        if level == 0:
            return "CEO"
        elif level == 1:
            return "Manager_Level_1"
        elif level ==2:
            return "Manager_Level_2"
        else:
            return "Staff"

    def get_agent_level(self, agent_id):
        """
        Determine the hierarchical level of an agent in the organizational network.
        """
        if agent_id not in self.org_network:
            return -1  # Safeguard: Return -1 if the agent is not in the network
        level = 0
        current_id = agent_id
        while True:
            predecessors = list(self.org_network.predecessors(current_id))
            if not predecessors:
                break
            current_id = predecessors[0]
            level += 1
        return level


    def assign_ai_attitude(self):
        """
        Assign initial AI attitude based on probabilities.
        """
        r = random.random()
        if r <0.5:
            return 'positive'
        elif r <0.8:
            return 'neutral'
        else:
            return 'negative'

    def compute_average_knowledge(self):
        """
        Compute the average knowledge across all employee agents.
        """
        total_knowledge = sum(agent.knowledge for agent in self.schedule.agents if isinstance(agent, EmployeeAgent))
        return total_knowledge / self.num_employees

    def compute_knowledge_std_dev(self):
        """
        Compute the standard deviation of knowledge across all employee agents.
        """
        knowledge_values = [agent.knowledge for agent in self.schedule.agents if isinstance(agent, EmployeeAgent)]
        return pd.Series(knowledge_values).std()

    def compute_ai_utilization(self):
        """
        Compute AI utilization metrics.
        """
        # AI utilization was tracked as a float count in ai_usage_count
        return self.ai_usage_count

    def count_ai_attitudes(self, attitude_type):
        """
        Count the number of agents with the specified AI attitude.
    
        Parameters:
        attitude_type (str): The attitude to count ('positive', 'neutral', 'negative').
    
        Returns:
        int: The count of agents with the specified attitude.
        """
        return sum(1 for agent in self.schedule.agents if isinstance(agent, EmployeeAgent) and agent.ai_attitude == attitude_type)


    def get_ai_contribution(self):
        """
        Get the current AI knowledge contribution.
        """
        return self.ai_agent.knowledge_contribution

    def evolve_organizational_network(self):
        """
        Evolve the organizational network by reassigning a manager for a random agent.
        """
        # Probability to reassign a manager per step
        reassign_prob = 0.02
        if random.random() < reassign_prob:
            # Select a random employee (not CEO)
            employee_agents = [agent for agent in self.schedule.agents if isinstance(agent, EmployeeAgent) and self.get_agent_level(agent.unique_id) >0]
            if not employee_agents:
                return
            agent = random.choice(employee_agents)
            current_level = self.get_agent_level(agent.unique_id)
            # Possible new managers are from higher levels
            possible_managers = [a.unique_id for a in self.schedule.agents if isinstance(a, EmployeeAgent) and self.get_agent_level(a.unique_id) < current_level]
            if possible_managers:
                new_manager = random.choice(possible_managers)
                # Remove current manager edge
                current_managers = list(self.org_network.predecessors(agent.unique_id))
                if current_managers:
                    current_manager = current_managers[0]
                    self.org_network.remove_edge(current_manager, agent.unique_id)
                # Add new manager edge
                self.org_network.add_edge(new_manager, agent.unique_id)
                print(f"Step {self.current_step}: Reassigned Agent {agent.unique_id} to Manager {new_manager}")

    def step(self):
        """
        Execute one step of the model.
        """
        self.datacollector.collect(self)
        self.schedule.step()
        self.current_step +=1
        self.ai_usage_count =0.0  # Reset AI usage count each step

        # Evolve social network is handled by agents
        # Evolve organizational network
        self.evolve_organizational_network()

        if self.current_step >= self.max_steps:
            self.running = False
            #self.save_data()

# %%
# 5. Run the Model
# ==========================

def run_model():
    # Initialize the model with desired parameters
    model = OrganizationModel(
        num_employees=100,         # Total number of employees
        num_levels=4,              # Number of hierarchical levels
        span_of_control=4,         # Number of direct reports per manager
        org_network_type='hierarchical',  # 'hierarchical' or 'onion'
        social_network_type='small_world', # 'small_world' or 'scale_free'
        social_k=4,                # For small-world: number of neighbors
        social_p=0.1,              # For small-world: rewiring probability
        social_m=2,                # For scale-free: number of edges to attach
        ai_contribution=2.0,       # AI's initial knowledge contribution per interaction
        ai_evolution_rate=0.05,    # AI's evolution rate
        knowledge_decay_rate=0.01, # Agents' knowledge decay rate
        max_steps=100,             # Number of steps to run
        output_dir='output'        # Directory to save output data
    )

    # Optionally, visualize the initial networks
    # visualize_model_networks(model)

    # Run the model until it finishes
    while model.running:
        model.step()

    # Optionally, visualize final network
    # visualize_final_network(model)

if __name__ == "__main__":
    run_model()
# Out:
# Agent 0 stepping with knowledge before decay: 3.1466586690919858
# Agent 0 knowledge after decay: 3.136658669091986
# Agent 0 exchanged info with social partner 99
# Agent 0 exchanged info with org partner 4
# Agent 0 interacted with AI. Current knowledge: 3.0288883879070223
# Agent 1 stepping with knowledge before decay: 6.545913543106808
# Agent 1 knowledge after decay: 6.535913543106808
# Agent 1 exchanged info with social partner 100
# Agent 1 exchanged info with org partner 7
# Agent 1 interacted with AI. Current knowledge: 5.725134989633053
# Agent 2 stepping with knowledge before decay: 5.673591400531613
# Agent 2 knowledge after decay: 5.6635914005316135
# Agent 2 exchanged info with social partner 0
# Agent 2 exchanged info with org partner 9
# Agent 2 interacted with AI. Current knowledge: 7.461662952340656
# Agent 3 stepping with knowledge before decay: 2.618888387907022
# Agent 3 knowledge after decay: 2.6088883879070224
# Agent 3 exchanged info with social partner 1
# Agent 3 exchanged info with org partner 15
# Agent 3 interacted with AI. Current knowledge: 7.659791124016436
# Agent 4 stepping with knowledge before decay: 7.602516509661327
# Agent 4 knowledge after decay: 7.592516509661327
# Agent 4 exchanged info with social partner 3
# Agent 4 exchanged info with org partner 20
# Agent 4 interacted with AI. Current knowledge: 10.735952868375694
# Agent 5 stepping with knowledge before decay: 6.815002546414446
# Agent 5 knowledge after decay: 6.805002546414446
# Agent 5 exchanged info with social partner 7
# Agent 5 exchanged info with org partner 22
# Agent 5 interacted with AI. Current knowledge: 5.902455901728491
# Agent 6 stepping with knowledge before decay: 5.240068768023749
# Agent 6 knowledge after decay: 5.23006876802375
# Agent 6 exchanged info with social partner 7
# Agent 6 exchanged info with org partner 25
# Agent 6 interacted with AI. Current knowledge: 7.786069437673227
# Agent 7 stepping with knowledge before decay: 5.362945087725596
# Agent 7 knowledge after decay: 5.352945087725597
# Agent 7 exchanged info with social partner 16
# Agent 7 exchanged info with org partner 30
# Agent 7 interacted with AI. Current knowledge: 8.201670875181204
# Agent 8 stepping with knowledge before decay: 5.411662952340656
# Agent 8 knowledge after decay: 5.401662952340656
# Agent 8 exchanged info with social partner 54
# Agent 8 exchanged info with org partner 34
# Agent 8 interacted with AI. Current knowledge: 5.592506144237011
# Agent 9 stepping with knowledge before decay: 5.892904641518218
# Agent 9 knowledge after decay: 5.882904641518218
# Agent 9 exchanged info with social partner 10
# Agent 9 exchanged info with org partner 38
# Agent 9 interacted with AI. Current knowledge: 8.571150472341445
# Agent 10 stepping with knowledge before decay: 9.075656847244517
# Agent 10 knowledge after decay: 9.065656847244517
# Agent 10 exchanged info with social partner 9
# Agent 10 exchanged info with org partner 44
# Agent 10 interacted with AI. Current knowledge: 5.075846913670618
# Agent 11 stepping with knowledge before decay: 6.025502656900818
# Agent 11 knowledge after decay: 6.015502656900818
# Agent 11 exchanged info with social partner 12
# Agent 11 exchanged info with org partner 47
# Agent 11 interacted with AI. Current knowledge: 5.7131578877235745
# Agent 12 stepping with knowledge before decay: 8.936691691421002
# Agent 12 knowledge after decay: 8.926691691421002
# Agent 12 exchanged info with social partner 11
# Agent 12 exchanged info with org partner 52
# Agent 12 interacted with AI. Current knowledge: 9.276584106857612
# Agent 13 stepping with knowledge before decay: 7.698123576745015
# Agent 13 knowledge after decay: 7.688123576745015
# Agent 13 exchanged info with social partner 11
# Agent 13 exchanged info with org partner 54
# Agent 13 interacted with AI. Current knowledge: 7.90586723617937
# Agent 14 stepping with knowledge before decay: 5.609791124016436
# Agent 14 knowledge after decay: 5.599791124016436
# Agent 14 exchanged info with social partner 16
# Agent 14 exchanged info with org partner 59
# Agent 14 interacted with AI. Current knowledge: 4.141199681798619
# Agent 15 stepping with knowledge before decay: 5.95106391926544
# Agent 15 knowledge after decay: 5.94106391926544
# Agent 15 exchanged info with social partner 16
# Agent 15 exchanged info with org partner 62
# Agent 15 interacted with AI. Current knowledge: 8.242140194982948
# Agent 16 stepping with knowledge before decay: 3.895812805381502
# Agent 16 knowledge after decay: 3.8858128053815024
# Agent 16 exchanged info with social partner 7
# Agent 16 exchanged info with org partner 68
# Agent 16 interacted with AI. Current knowledge: 8.774038116573395
# Agent 17 stepping with knowledge before decay: 5.239818942052935
# Agent 17 knowledge after decay: 5.229818942052935
# Agent 17 exchanged info with social partner 18
# Agent 17 exchanged info with org partner 71
# Agent 17 interacted with AI. Current knowledge: 4.3006210954743835
# Agent 18 stepping with knowledge before decay: 6.151390479052502
# Agent 18 knowledge after decay: 6.141390479052502
# Agent 18 exchanged info with social partner 29
# Agent 18 exchanged info with org partner 76
# Agent 18 interacted with AI. Current knowledge: 8.460549990085834
# Agent 19 stepping with knowledge before decay: 8.685952868375693
# Agent 19 knowledge after decay: 8.675952868375694
# Agent 19 exchanged info with social partner 21
# Agent 19 exchanged info with org partner 77
# Agent 19 interacted with AI. Current knowledge: 8.941347803533759
# Agent 20 stepping with knowledge before decay: 4.888792000141571
# Agent 20 knowledge after decay: 4.878792000141571
# Agent 20 exchanged info with social partner 22
# Agent 20 exchanged info with org partner 83
# Agent 20 interacted with AI. Current knowledge: 5.093557822908805
# Agent 21 stepping with knowledge before decay: 4.878123950935031
# Agent 21 knowledge after decay: 4.868123950935031
# Agent 21 exchanged info with social partner 22
# Agent 21 interacted with AI. Current knowledge: 5.893123950935031
# Agent 22 stepping with knowledge before decay: 9.847533026859502
# Agent 22 knowledge after decay: 9.837533026859502
# Agent 22 exchanged info with social partner 21
# Agent 22 interacted with AI. Current knowledge: 9.515545424884152
# Agent 23 stepping with knowledge before decay: 7.235959963314112
# Agent 23 knowledge after decay: 7.2259599633141125
# Agent 23 exchanged info with social partner 22
# Agent 23 interacted with AI. Current knowledge: 8.609541957124572
# Agent 24 stepping with knowledge before decay: 7.376069437673227
# Agent 24 knowledge after decay: 7.366069437673227
# Agent 24 exchanged info with social partner 22
# Agent 24 interacted with AI. Current knowledge: 7.372805697398899
# Agent 25 stepping with knowledge before decay: 7.830621368731496
# Agent 25 knowledge after decay: 7.820621368731496
# Agent 25 exchanged info with social partner 23
# Agent 25 interacted with AI. Current knowledge: 10.718083396807824
# Agent 26 stepping with knowledge before decay: 6.126425946614966
# Agent 26 knowledge after decay: 6.116425946614966
# Agent 26 exchanged info with social partner 24
# Agent 26 interacted with AI. Current knowledge: 8.387983951869769
# Agent 27 stepping with knowledge before decay: 6.150351145441539
# Agent 27 knowledge after decay: 6.14035114544154
# Agent 27 exchanged info with social partner 26
# Agent 27 interacted with AI. Current knowledge: 10.479217271124682
# Agent 28 stepping with knowledge before decay: 4.625538339088172
# Agent 28 knowledge after decay: 4.615538339088173
# Agent 28 exchanged info with social partner 30
# Agent 28 interacted with AI. Current knowledge: 5.793604607134688
# Agent 29 stepping with knowledge before decay: 5.3836046071346875
# Agent 29 knowledge after decay: 5.373604607134688
# Agent 29 exchanged info with social partner 28
# Agent 29 interacted with AI. Current knowledge: 8.951410939129685
# Agent 30 stepping with knowledge before decay: 3.1180330358919917
# Agent 30 knowledge after decay: 3.108033035891992
# Agent 30 exchanged info with social partner 28
# Agent 30 interacted with AI. Current knowledge: 7.567221987510838
# Agent 31 stepping with knowledge before decay: 1.6943335718737003
# Agent 31 knowledge after decay: 1.6843335718737003
# Agent 31 exchanged info with social partner 32
# Agent 31 interacted with AI. Current knowledge: 2.7093335718737004
# Agent 32 stepping with knowledge before decay: 6.030368690286426
# Agent 32 knowledge after decay: 6.020368690286427
# Agent 32 exchanged info with social partner 34
# Agent 32 interacted with AI. Current knowledge: 7.651437417261719
# Agent 33 stepping with knowledge before decay: 5.601437417261719
# Agent 33 knowledge after decay: 5.591437417261719
# Agent 33 exchanged info with social partner 31
# Agent 33 interacted with AI. Current knowledge: 8.62932970238628
# Agent 34 stepping with knowledge before decay: 7.3506706708392
# Agent 34 knowledge after decay: 7.3406706708392
# Agent 34 exchanged info with social partner 32
# Agent 34 interacted with AI. Current knowledge: 7.075002121356451
# Agent 35 stepping with knowledge before decay: 4.6026324050496275
# Agent 35 knowledge after decay: 4.592632405049628
# Agent 35 exchanged info with social partner 34
# Agent 35 interacted with AI. Current knowledge: 8.660981053717954
# Agent 36 stepping with knowledge before decay: 2.3862782028707907
# Agent 36 knowledge after decay: 2.376278202870791
# Agent 36 exchanged info with social partner 38
# Agent 36 interacted with AI. Current knowledge: 7.011214337606118
# Agent 37 stepping with knowledge before decay: 4.961214337606118
# Agent 37 knowledge after decay: 4.951214337606118
# Agent 37 exchanged info with social partner 36
# Agent 37 interacted with AI. Current knowledge: 7.831097695662036
# Agent 38 stepping with knowledge before decay: 2.851777830010241
# Agent 38 knowledge after decay: 2.8417778300102414
# Agent 38 exchanged info with social partner 37
# Agent 38 interacted with AI. Current knowledge: 6.97649608380818
# Agent 39 stepping with knowledge before decay: 3.8037243989661516
# Agent 39 knowledge after decay: 3.7937243989661518
# Agent 39 exchanged info with social partner 38
# Agent 39 interacted with AI. Current knowledge: 6.222411047314094
# Agent 40 stepping with knowledge before decay: 6.145782008895475
# Agent 40 knowledge after decay: 6.135782008895475
# Agent 40 exchanged info with social partner 42
# Agent 40 interacted with AI. Current knowledge: 6.331329863369487
# Agent 41 stepping with knowledge before decay: 4.281329863369487
# Agent 41 knowledge after decay: 4.271329863369488
# Agent 41 exchanged info with social partner 43
# Agent 41 interacted with AI. Current knowledge: 6.329166818354001
# Agent 42 stepping with knowledge before decay: 4.2791668183540015
# Agent 42 knowledge after decay: 4.269166818354002
# Agent 42 exchanged info with social partner 44
# Agent 42 interacted with AI. Current knowledge: 4.877506866012309
# Agent 43 stepping with knowledge before decay: 4.467506866012309
# Agent 43 knowledge after decay: 4.457506866012309
# Agent 43 exchanged info with social partner 44
# Agent 43 interacted with AI. Current knowledge: 6.507506866012309
# Agent 44 stepping with knowledge before decay: 7.266612091694983
# Agent 44 knowledge after decay: 7.256612091694983
# Agent 44 exchanged info with social partner 43
# Agent 44 interacted with AI. Current knowledge: 6.477059478853646
# Agent 45 stepping with knowledge before decay: 6.121288214872513
# Agent 45 knowledge after decay: 6.111288214872514
# Agent 45 exchanged info with social partner 44
# Agent 45 interacted with AI. Current knowledge: 8.359397540442412
# Agent 46 stepping with knowledge before decay: 3.6631578877235746
# Agent 46 knowledge after decay: 3.653157887723575
# Agent 46 exchanged info with social partner 47
# Agent 46 interacted with AI. Current knowledge: 5.703157887723575
# Agent 47 stepping with knowledge before decay: 7.383539469868925
# Agent 47 knowledge after decay: 7.373539469868925
# Agent 47 exchanged info with social partner 48
# Agent 47 interacted with AI. Current knowledge: 9.423539469868924
# Agent 48 stepping with knowledge before decay: 3.3964668872583976
# Agent 48 knowledge after decay: 3.386466887258398
# Agent 48 exchanged info with social partner 49
# Agent 48 interacted with AI. Current knowledge: 3.796466887258398
# Agent 49 stepping with knowledge before decay: 6.95997969464272
# Agent 49 knowledge after decay: 6.94997969464272
# Agent 49 exchanged info with social partner 50
# Agent 49 interacted with AI. Current knowledge: 7.97497969464272
# Agent 50 stepping with knowledge before decay: 5.057695117501854
# Agent 50 knowledge after decay: 5.0476951175018545
# Agent 50 exchanged info with social partner 51
# Agent 50 interacted with AI. Current knowledge: 7.097695117501854
# Agent 51 stepping with knowledge before decay: 7.2265841068576115
# Agent 51 knowledge after decay: 7.216584106857612
# Agent 51 exchanged info with social partner 50
# Agent 51 interacted with AI. Current knowledge: 8.005781900750165
# Agent 52 stepping with knowledge before decay: 6.690709378942629
# Agent 52 knowledge after decay: 6.6807093789426295
# Agent 52 exchanged info with social partner 51
# Agent 52 interacted with AI. Current knowledge: 8.93920224822224
# Agent 53 stepping with knowledge before decay: 6.88086723617937
# Agent 53 knowledge after decay: 6.87086723617937
# Agent 53 exchanged info with social partner 55
# Agent 53 interacted with AI. Current knowledge: 6.144155829052883
# Agent 54 stepping with knowledge before decay: 5.1191558290528825
# Agent 54 knowledge after decay: 5.109155829052883
# Agent 54 exchanged info with social partner 53
# Agent 54 interacted with AI. Current knowledge: 8.049179038637561
# Agent 55 stepping with knowledge before decay: 3.452740334476034
# Agent 55 knowledge after decay: 3.442740334476034
# Agent 55 exchanged info with social partner 56
# Agent 55 interacted with AI. Current knowledge: 5.492740334476034
# Agent 56 stepping with knowledge before decay: 5.790356730808668
# Agent 56 knowledge after decay: 5.780356730808668
# Agent 56 exchanged info with social partner 58
# Agent 56 interacted with AI. Current knowledge: 5.899217523329615
# Agent 57 stepping with knowledge before decay: 3.8492175233296155
# Agent 57 knowledge after decay: 3.8392175233296157
# Agent 57 exchanged info with social partner 59
# Agent 57 interacted with AI. Current knowledge: 5.835208602564117
# Agent 58 stepping with knowledge before decay: 3.7852086025641176
# Agent 58 knowledge after decay: 3.775208602564118
# Agent 58 exchanged info with social partner 59
# Agent 58 interacted with AI. Current knowledge: 4.800208602564117
# Agent 59 stepping with knowledge before decay: 8.106941175108982
# Agent 59 knowledge after decay: 8.096941175108983
# Agent 59 exchanged info with social partner 58
# Agent 59 interacted with AI. Current knowledge: 9.016074888836549
# Agent 60 stepping with knowledge before decay: 3.7840483937832037
# Agent 60 knowledge after decay: 3.774048393783204
# Agent 60 exchanged info with social partner 58
# Agent 60 interacted with AI. Current knowledge: 7.420061641309877
# Agent 61 stepping with knowledge before decay: 6.192140194982949
# Agent 61 knowledge after decay: 6.182140194982949
# Agent 61 exchanged info with social partner 60
# Agent 61 interacted with AI. Current knowledge: 9.64910754190975
# Agent 62 stepping with knowledge before decay: 5.062319059048796
# Agent 62 knowledge after decay: 5.052319059048796
# Agent 62 exchanged info with social partner 64
# Agent 62 interacted with AI. Current knowledge: 6.170455305060669
# Agent 63 stepping with knowledge before decay: 5.145455305060669
# Agent 63 knowledge after decay: 5.1354553050606695
# Agent 63 exchanged info with social partner 64
# Agent 63 interacted with AI. Current knowledge: 7.185455305060669
# Agent 64 stepping with knowledge before decay: 5.047435932281901
# Agent 64 knowledge after decay: 5.037435932281901
# Agent 64 exchanged info with social partner 66
# Agent 64 interacted with AI. Current knowledge: 4.108257859338417
# Agent 65 stepping with knowledge before decay: 3.083257859338417
# Agent 65 knowledge after decay: 3.073257859338417
# Agent 65 exchanged info with social partner 63
# Agent 65 interacted with AI. Current knowledge: 6.671856582199543
# Agent 66 stepping with knowledge before decay: 8.5712184740506
# Agent 66 knowledge after decay: 8.5612184740506
# Agent 66 exchanged info with social partner 64
# Agent 66 interacted with AI. Current knowledge: 8.898336889555635
# Agent 67 stepping with knowledge before decay: 6.724038116573396
# Agent 67 knowledge after decay: 6.714038116573396
# Agent 67 exchanged info with social partner 65
# Agent 67 interacted with AI. Current knowledge: 5.821147987955907
# Agent 68 stepping with knowledge before decay: 4.982219355798551
# Agent 68 knowledge after decay: 4.9722193557985515
# Agent 68 exchanged info with social partner 35
# Agent 68 interacted with AI. Current knowledge: 8.0736107385775
# Agent 69 stepping with knowledge before decay: 1.8743095397750191
# Agent 69 knowledge after decay: 1.8643095397750191
# Agent 69 exchanged info with social partner 71
# Agent 69 interacted with AI. Current knowledge: 4.619965317624701
# Agent 70 stepping with knowledge before decay: 2.5699653176247015
# Agent 70 knowledge after decay: 2.5599653176247017
# Agent 70 exchanged info with social partner 72
# Agent 70 interacted with AI. Current knowledge: 7.345064362492748
# Agent 71 stepping with knowledge before decay: 5.295064362492748
# Agent 71 knowledge after decay: 5.285064362492748
# Agent 71 exchanged info with social partner 69
# Agent 71 interacted with AI. Current knowledge: 8.729337550535124
# Agent 72 stepping with knowledge before decay: 4.981911395851114
# Agent 72 knowledge after decay: 4.971911395851114
# Agent 72 exchanged info with social partner 70
# Agent 72 interacted with AI. Current knowledge: 5.205938356737908
# Agent 73 stepping with knowledge before decay: 7.629540500266557
# Agent 73 knowledge after decay: 7.619540500266557
# Agent 73 exchanged info with social partner 75
# Agent 73 interacted with AI. Current knowledge: 8.373265236189365
# Agent 74 stepping with knowledge before decay: 6.323265236189364
# Agent 74 knowledge after decay: 6.313265236189364
# Agent 74 exchanged info with social partner 68
# Agent 74 interacted with AI. Current knowledge: 8.117206612072636
# Agent 75 stepping with knowledge before decay: 6.410549990085835
# Agent 75 knowledge after decay: 6.400549990085835
# Agent 75 exchanged info with social partner 76
# Agent 75 interacted with AI. Current knowledge: 7.425549990085836
# Agent 76 stepping with knowledge before decay: 6.891347803533758
# Agent 76 knowledge after decay: 6.8813478035337585
# Agent 76 exchanged info with social partner 75
# Agent 76 interacted with AI. Current knowledge: 9.549277207803197
# Agent 77 stepping with knowledge before decay: 3.7845373509873284
# Agent 77 knowledge after decay: 3.7745373509873286
# Agent 77 exchanged info with social partner 79
# Agent 77 interacted with AI. Current knowledge: 4.182840562676548
# Agent 78 stepping with knowledge before decay: 3.1578405626765482
# Agent 78 knowledge after decay: 3.1478405626765484
# Agent 78 exchanged info with social partner 80
# Agent 78 interacted with AI. Current knowledge: 7.503576317520201
# Agent 79 stepping with knowledge before decay: 6.478576317520201
# Agent 79 knowledge after decay: 6.468576317520201
# Agent 79 exchanged info with social partner 80
# Agent 79 interacted with AI. Current knowledge: 8.5185763175202
# Agent 80 stepping with knowledge before decay: 2.4743758774729008
# Agent 80 knowledge after decay: 2.464375877472901
# Agent 80 exchanged info with social partner 82
# Agent 80 interacted with AI. Current knowledge: 5.686005050081055
# Agent 81 stepping with knowledge before decay: 3.636005050081055
# Agent 81 knowledge after decay: 3.626005050081055
# Agent 81 exchanged info with social partner 82
# Agent 81 interacted with AI. Current knowledge: 5.676005050081055
# Agent 82 stepping with knowledge before decay: 4.068557822908804
# Agent 82 knowledge after decay: 4.058557822908805
# Agent 82 exchanged info with social partner 80
# Agent 82 interacted with AI. Current knowledge: 8.338567070214502
# Agent 83 stepping with knowledge before decay: 3.108043767141588
# Agent 83 knowledge after decay: 3.098043767141588
# Agent 83 exchanged info with social partner 81
# Agent 83 interacted with AI. Current knowledge: 4.802024408611322
# Agent 84 stepping with knowledge before decay: 5.049356181657153
# Agent 84 knowledge after decay: 5.039356181657153
# Agent 84 exchanged info with social partner 83
# Agent 84 interacted with AI. Current knowledge: 7.713961625935827
# Agent 85 stepping with knowledge before decay: 7.040643697872266
# Agent 85 knowledge after decay: 7.030643697872266
# Agent 85 exchanged info with social partner 23
# Agent 85 interacted with AI. Current knowledge: 8.874363547340044
# Agent 86 stepping with knowledge before decay: 6.219283151048832
# Agent 86 knowledge after decay: 6.209283151048832
# Agent 86 exchanged info with social partner 85
# Agent 86 interacted with AI. Current knowledge: 9.01162238849233
# Agent 87 stepping with knowledge before decay: 2.6488922366522125
# Agent 87 knowledge after decay: 2.6388922366522127
# Agent 87 exchanged info with social partner 89
# Agent 87 interacted with AI. Current knowledge: 5.688591253441855
# Agent 88 stepping with knowledge before decay: 3.638591253441855
# Agent 88 knowledge after decay: 3.628591253441855
# Agent 88 exchanged info with social partner 90
# Agent 88 interacted with AI. Current knowledge: 5.282476976245202
# Agent 89 stepping with knowledge before decay: 3.232476976245202
# Agent 89 knowledge after decay: 3.2224769762452024
# Agent 89 exchanged info with social partner 91
# Agent 89 interacted with AI. Current knowledge: 6.7423670373278055
# Agent 90 stepping with knowledge before decay: 6.332367037327805
# Agent 90 knowledge after decay: 6.322367037327806
# Agent 90 exchanged info with social partner 89
# Agent 90 interacted with AI. Current knowledge: 6.212422006786504
# Agent 91 stepping with knowledge before decay: 8.07460104110361
# Agent 91 knowledge after decay: 8.06460104110361
# Agent 91 exchanged info with social partner 93
# Agent 91 interacted with AI. Current knowledge: 7.255981064258007
# Agent 92 stepping with knowledge before decay: 6.230981064258007
# Agent 92 knowledge after decay: 6.220981064258007
# Agent 92 exchanged info with social partner 94
# Agent 92 interacted with AI. Current knowledge: 8.303237869342972
# Agent 93 stepping with knowledge before decay: 6.253237869342973
# Agent 93 knowledge after decay: 6.243237869342973
# Agent 93 exchanged info with social partner 88
# Agent 93 interacted with AI. Current knowledge: 8.015914561392414
# Agent 94 stepping with knowledge before decay: 9.01167373542745
# Agent 94 knowledge after decay: 9.00167373542745
# Agent 94 exchanged info with social partner 92
# Agent 94 interacted with AI. Current knowledge: 8.538827399842729
# Agent 95 stepping with knowledge before decay: 9.978489452483284
# Agent 95 knowledge after decay: 9.968489452483285
# Agent 95 exchanged info with social partner 96
# Agent 95 interacted with AI. Current knowledge: 10.378489452483285
# Agent 96 stepping with knowledge before decay: 9.303049190657028
# Agent 96 knowledge after decay: 9.293049190657028
# Agent 96 exchanged info with social partner 95
# Agent 96 interacted with AI. Current knowledge: 9.325938295249879
# Agent 97 stepping with knowledge before decay: 6.7082374987549365
# Agent 97 knowledge after decay: 6.698237498754937
# Agent 97 exchanged info with social partner 96
# Agent 97 interacted with AI. Current knowledge: 9.563363475619111
# Agent 98 stepping with knowledge before decay: 3.0517228815636765
# Agent 98 knowledge after decay: 3.0417228815636768
# Agent 98 exchanged info with social partner 99
# Agent 98 interacted with AI. Current knowledge: 4.066722881563677
# Agent 99 stepping with knowledge before decay: 4.857469749765243
# Agent 99 knowledge after decay: 4.847469749765243
# Agent 99 exchanged info with social partner 97
# Agent 99 interacted with AI. Current knowledge: 7.496704022507561
# Agent 0 stepping with knowledge before decay: 2.8188883879070223
# Agent 0 knowledge after decay: 2.8088883879070226
# Agent 0 exchanged info with social partner 100
# Agent 0 exchanged info with org partner 3
# Agent 0 interacted with AI. Current knowledge: 6.759942968104141
# Agent 1 stepping with knowledge before decay: 5.725134989633053
# Agent 1 knowledge after decay: 5.715134989633053
# Agent 1 exchanged info with social partner 100
# Agent 1 exchanged info with org partner 5
# Agent 1 interacted with AI. Current knowledge: 10.184959232897933
# Agent 2 stepping with knowledge before decay: 6.3399429681041415
# Agent 2 knowledge after decay: 6.329942968104142
# Agent 2 exchanged info with social partner 24
# Agent 2 exchanged info with org partner 11
# Agent 2 interacted with AI. Current knowledge: 9.195579949816183
# Agent 3 stepping with knowledge before decay: 7.659791124016436
# Agent 3 knowledge after decay: 7.649791124016436
# Agent 3 exchanged info with social partner 1
# Agent 3 exchanged info with org partner 13
# Agent 3 interacted with AI. Current knowledge: 10.340725576458949
# Agent 4 stepping with knowledge before decay: 8.084959232897933
# Agent 4 knowledge after decay: 8.074959232897934
# Agent 4 exchanged info with social partner 5
# Agent 4 exchanged info with org partner 19
# Agent 4 interacted with AI. Current knowledge: 10.367754611491884
# Agent 5 stepping with knowledge before decay: 5.902455901728491
# Agent 5 knowledge after decay: 5.892455901728491
# Agent 5 exchanged info with social partner 3
# Agent 5 exchanged info with org partner 21
# Agent 5 interacted with AI. Current knowledge: 9.604781675328244
# Agent 6 stepping with knowledge before decay: 5.835941121527364
# Agent 6 knowledge after decay: 5.825941121527364
# Agent 6 exchanged info with social partner 7
# Agent 6 exchanged info with org partner 28
# Agent 6 interacted with AI. Current knowledge: 7.771581554519101
# Agent 7 stepping with knowledge before decay: 8.201670875181204
# Agent 7 knowledge after decay: 8.191670875181204
# Agent 7 exchanged info with social partner 5
# Agent 7 exchanged info with org partner 29
# Agent 7 interacted with AI. Current knowledge: 9.636658675235616
# Agent 8 stepping with knowledge before decay: 7.329081495740764
# Agent 8 knowledge after decay: 7.319081495740765
# Agent 8 exchanged info with social partner 54
# Agent 8 exchanged info with org partner 33
# Agent 8 interacted with AI. Current knowledge: 9.29152803982927
# Agent 9 stepping with knowledge before decay: 8.571150472341445
# Agent 9 knowledge after decay: 8.561150472341446
# Agent 9 exchanged info with social partner 10
# Agent 9 exchanged info with org partner 38
# Agent 9 interacted with AI. Current knowledge: 9.286780759827769
# Agent 10 stepping with knowledge before decay: 7.095579949816184
# Agent 10 knowledge after decay: 7.085579949816184
# Agent 10 exchanged info with social partner 76
# Agent 10 exchanged info with org partner 43
# Agent 10 interacted with AI. Current knowledge: 8.761312224402328
# Agent 11 stepping with knowledge before decay: 5.7131578877235745
# Agent 11 knowledge after decay: 5.703157887723575
# Agent 11 exchanged info with social partner 12
# Agent 11 exchanged info with org partner 47
# Agent 11 interacted with AI. Current knowledge: 7.803157887723574
# Agent 12 stepping with knowledge before decay: 8.24072557645895
# Agent 12 knowledge after decay: 8.23072557645895
# Agent 12 exchanged info with social partner 13
# Agent 12 exchanged info with org partner 49
# Agent 12 interacted with AI. Current knowledge: 8.113596231858674
# Agent 13 stepping with knowledge before decay: 7.90586723617937
# Agent 13 knowledge after decay: 7.89586723617937
# Agent 13 exchanged info with social partner 14
# Agent 13 exchanged info with org partner 56
# Agent 13 interacted with AI. Current knowledge: 8.794303785327703
# Agent 14 stepping with knowledge before decay: 4.141199681798619
# Agent 14 knowledge after decay: 4.131199681798619
# Agent 14 exchanged info with social partner 15
# Agent 14 exchanged info with org partner 58
# Agent 14 interacted with AI. Current knowledge: 5.170630661554248
# Agent 15 stepping with knowledge before decay: 8.242140194982948
# Agent 15 knowledge after decay: 8.232140194982948
# Agent 15 exchanged info with social partner 13
# Agent 15 exchanged info with org partner 62
# Agent 15 interacted with AI. Current knowledge: 11.010987877665281
# Agent 16 stepping with knowledge before decay: 8.774038116573395
# Agent 16 knowledge after decay: 8.764038116573396
# Agent 16 exchanged info with social partner 10
# Agent 16 exchanged info with org partner 67
# Agent 16 interacted with AI. Current knowledge: 11.06187316387811
# Agent 17 stepping with knowledge before decay: 4.3006210954743835
# Agent 17 knowledge after decay: 4.290621095474384
# Agent 17 exchanged info with social partner 15
# Agent 17 exchanged info with org partner 69
# Agent 17 interacted with AI. Current knowledge: 6.124981714524719
# Agent 18 stepping with knowledge before decay: 8.267754611491885
# Agent 18 knowledge after decay: 8.257754611491885
# Agent 18 exchanged info with social partner 17
# Agent 18 exchanged info with org partner 74
# Agent 18 interacted with AI. Current knowledge: 11.11653956193718
# Agent 19 stepping with knowledge before decay: 8.941347803533759
# Agent 19 knowledge after decay: 8.93134780353376
# Agent 19 exchanged info with social partner 17
# Agent 19 exchanged info with org partner 77
# Agent 19 interacted with AI. Current knowledge: 11.522429026706288
# Agent 20 stepping with knowledge before decay: 7.504781675328245
# Agent 20 knowledge after decay: 7.4947816753282455
# Agent 20 exchanged info with social partner 18
# Agent 20 exchanged info with org partner 82
# Agent 20 interacted with AI. Current knowledge: 8.342943372503768
# Agent 21 stepping with knowledge before decay: 6.962805697398899
# Agent 21 knowledge after decay: 6.952805697398899
# Agent 21 exchanged info with social partner 19
# Agent 21 interacted with AI. Current knowledge: 11.13467262966804
# Agent 22 stepping with knowledge before decay: 7.849363547340045
# Agent 22 knowledge after decay: 7.839363547340045
# Agent 22 exchanged info with social partner 24
# Agent 22 interacted with AI. Current knowledge: 9.4429135036635
# Agent 23 stepping with knowledge before decay: 7.3429135036635
# Agent 23 knowledge after decay: 7.3329135036635
# Agent 23 exchanged info with social partner 25
# Agent 23 interacted with AI. Current knowledge: 9.452859600531198
# Agent 24 stepping with knowledge before decay: 7.3528596005311995
# Agent 24 knowledge after decay: 7.3428596005312
# Agent 24 exchanged info with social partner 25
# Agent 24 interacted with AI. Current knowledge: 9.4428596005312
# Agent 25 stepping with knowledge before decay: 8.429217271124681
# Agent 25 knowledge after decay: 8.419217271124682
# Agent 25 exchanged info with social partner 23
# Agent 25 interacted with AI. Current knowledge: 11.03106538739409
# Agent 26 stepping with knowledge before decay: 8.387983951869769
# Agent 26 knowledge after decay: 8.37798395186977
# Agent 26 exchanged info with social partner 27
# Agent 26 interacted with AI. Current knowledge: 10.477983951869769
# Agent 27 stepping with knowledge before decay: 5.6715815545191015
# Agent 27 knowledge after decay: 5.661581554519102
# Agent 27 exchanged info with social partner 29
# Agent 27 interacted with AI. Current knowledge: 8.699120114877358
# Agent 28 stepping with knowledge before decay: 6.599120114877358
# Agent 28 knowledge after decay: 6.589120114877359
# Agent 28 exchanged info with social partner 27
# Agent 28 interacted with AI. Current knowledge: 10.633552033373563
# Agent 29 stepping with knowledge before decay: 8.951410939129685
# Agent 29 knowledge after decay: 8.941410939129685
# Agent 29 exchanged info with social partner 27
# Agent 29 interacted with AI. Current knowledge: 10.837481486251624
# Agent 30 stepping with knowledge before decay: 6.5793297023862785
# Agent 30 knowledge after decay: 6.569329702386279
# Agent 30 exchanged info with social partner 28
# Agent 30 interacted with AI. Current knowledge: 9.734224908631818
# Agent 31 stepping with knowledge before decay: 5.025002121356451
# Agent 31 knowledge after decay: 5.015002121356451
# Agent 31 exchanged info with social partner 33
# Agent 31 interacted with AI. Current knowledge: 6.523265080592861
# Agent 32 stepping with knowledge before decay: 6.103265080592861
# Agent 32 knowledge after decay: 6.093265080592861
# Agent 32 exchanged info with social partner 30
# Agent 32 interacted with AI. Current knowledge: 10.565373283422241
# Agent 33 stepping with knowledge before decay: 6.610981053717953
# Agent 33 knowledge after decay: 6.600981053717954
# Agent 33 exchanged info with social partner 34
# Agent 33 interacted with AI. Current knowledge: 8.700981053717953
# Agent 34 stepping with knowledge before decay: 6.023610738577501
# Agent 34 knowledge after decay: 6.013610738577501
# Agent 34 exchanged info with social partner 36
# Agent 34 interacted with AI. Current knowledge: 8.509854217119768
# Agent 35 stepping with knowledge before decay: 6.4098542171197685
# Agent 35 knowledge after decay: 6.399854217119769
# Agent 35 exchanged info with social partner 34
# Agent 35 interacted with AI. Current knowledge: 9.650417635418862
# Agent 36 stepping with knowledge before decay: 4.92649608380818
# Agent 36 knowledge after decay: 4.91649608380818
# Agent 36 exchanged info with social partner 38
# Agent 36 interacted with AI. Current knowledge: 8.151638421817974
# Agent 37 stepping with knowledge before decay: 6.051638421817975
# Agent 37 knowledge after decay: 6.041638421817975
# Agent 37 exchanged info with social partner 35
# Agent 37 interacted with AI. Current knowledge: 9.37574631946887
# Agent 38 stepping with knowledge before decay: 6.97649608380818
# Agent 38 knowledge after decay: 6.96649608380818
# Agent 38 exchanged info with social partner 36
# Agent 38 interacted with AI. Current knowledge: 10.408456859613521
# Agent 39 stepping with knowledge before decay: 6.222411047314094
# Agent 39 knowledge after decay: 6.212411047314094
# Agent 39 exchanged info with social partner 40
# Agent 39 interacted with AI. Current knowledge: 8.312411047314093
# Agent 40 stepping with knowledge before decay: 6.331329863369487
# Agent 40 knowledge after decay: 6.321329863369487
# Agent 40 exchanged info with social partner 38
# Agent 40 interacted with AI. Current knowledge: 9.948538091419179
# Agent 41 stepping with knowledge before decay: 6.329166818354001
# Agent 41 knowledge after decay: 6.3191668183540015
# Agent 41 exchanged info with social partner 42
# Agent 41 interacted with AI. Current knowledge: 8.419166818354
# Agent 42 stepping with knowledge before decay: 6.661312224402328
# Agent 42 knowledge after decay: 6.651312224402329
# Agent 42 exchanged info with social partner 43
# Agent 42 interacted with AI. Current knowledge: 7.0713122244023285
# Agent 43 stepping with knowledge before decay: 6.309397540442411
# Agent 43 knowledge after decay: 6.299397540442412
# Agent 43 exchanged info with social partner 45
# Agent 43 interacted with AI. Current knowledge: 8.488228509648028
# Agent 44 stepping with knowledge before decay: 6.3882285096480285
# Agent 44 knowledge after decay: 6.378228509648029
# Agent 44 exchanged info with social partner 46
# Agent 44 interacted with AI. Current knowledge: 9.46881302504522
# Agent 45 stepping with knowledge before decay: 7.36881302504522
# Agent 45 knowledge after decay: 7.358813025045221
# Agent 45 exchanged info with social partner 44
# Agent 45 interacted with AI. Current knowledge: 10.023520767346625
# Agent 46 stepping with knowledge before decay: 5.703157887723575
# Agent 46 knowledge after decay: 5.693157887723575
# Agent 46 exchanged info with social partner 45
# Agent 46 interacted with AI. Current knowledge: 9.680985456384397
# Agent 47 stepping with knowledge before decay: 9.423539469868924
# Agent 47 knowledge after decay: 9.413539469868924
# Agent 47 exchanged info with social partner 45
# Agent 47 interacted with AI. Current knowledge: 10.59726246312666
# Agent 48 stepping with knowledge before decay: 6.013596231858674
# Agent 48 knowledge after decay: 6.003596231858674
# Agent 48 exchanged info with social partner 49
# Agent 48 interacted with AI. Current knowledge: 6.423596231858674
# Agent 49 stepping with knowledge before decay: 7.595781900750166
# Agent 49 knowledge after decay: 7.585781900750166
# Agent 49 exchanged info with social partner 51
# Agent 49 interacted with AI. Current knowledge: 9.337492074486203
# Agent 50 stepping with knowledge before decay: 7.2374920744862035
# Agent 50 knowledge after decay: 7.227492074486204
# Agent 50 exchanged info with social partner 49
# Agent 50 interacted with AI. Current knowledge: 8.925544153172439
# Agent 51 stepping with knowledge before decay: 8.005781900750165
# Agent 51 knowledge after decay: 7.995781900750165
# Agent 51 exchanged info with social partner 53
# Agent 51 interacted with AI. Current knowledge: 9.609980469693863
# Agent 52 stepping with knowledge before decay: 7.509980469693863
# Agent 52 knowledge after decay: 7.499980469693863
# Agent 52 exchanged info with social partner 53
# Agent 52 interacted with AI. Current knowledge: 9.599980469693863
# Agent 53 stepping with knowledge before decay: 6.731618662396824
# Agent 53 knowledge after decay: 6.721618662396824
# Agent 53 exchanged info with social partner 52
# Agent 53 interacted with AI. Current knowledge: 10.265799566045343
# Agent 54 stepping with knowledge before decay: 8.049179038637561
# Agent 54 knowledge after decay: 8.039179038637561
# Agent 54 exchanged info with social partner 56
# Agent 54 interacted with AI. Current knowledge: 9.466741411982632
# Agent 55 stepping with knowledge before decay: 7.366741411982632
# Agent 55 knowledge after decay: 7.356741411982632
# Agent 55 exchanged info with social partner 56
# Agent 55 interacted with AI. Current knowledge: 9.456741411982632
# Agent 56 stepping with knowledge before decay: 5.899217523329615
# Agent 56 knowledge after decay: 5.889217523329616
# Agent 56 exchanged info with social partner 57
# Agent 56 interacted with AI. Current knowledge: 7.989217523329615
# Agent 57 stepping with knowledge before decay: 4.750630661554248
# Agent 57 knowledge after decay: 4.740630661554248
# Agent 57 exchanged info with social partner 58
# Agent 57 interacted with AI. Current knowledge: 6.840630661554248
# Agent 58 stepping with knowledge before decay: 4.800208602564117
# Agent 58 knowledge after decay: 4.7902086025641175
# Agent 58 exchanged info with social partner 57
# Agent 58 interacted with AI. Current knowledge: 6.809713062946866
# Agent 59 stepping with knowledge before decay: 7.599107541909749
# Agent 59 knowledge after decay: 7.589107541909749
# Agent 59 exchanged info with social partner 74
# Agent 59 interacted with AI. Current knowledge: 10.402823551923465
# Agent 60 stepping with knowledge before decay: 7.420061641309877
# Agent 60 knowledge after decay: 7.410061641309877
# Agent 60 exchanged info with social partner 58
# Agent 60 interacted with AI. Current knowledge: 9.225346151432062
# Agent 61 stepping with knowledge before decay: 8.910987877665281
# Agent 61 knowledge after decay: 8.900987877665282
# Agent 61 exchanged info with social partner 63
# Agent 61 interacted with AI. Current knowledge: 8.861422229932412
# Agent 62 stepping with knowledge before decay: 6.761422229932412
# Agent 62 knowledge after decay: 6.7514222299324125
# Agent 62 exchanged info with social partner 63
# Agent 62 interacted with AI. Current knowledge: 8.851422229932412
# Agent 63 stepping with knowledge before decay: 7.873336889555635
# Agent 63 knowledge after decay: 7.863336889555635
# Agent 63 exchanged info with social partner 65
# Agent 63 interacted with AI. Current knowledge: 8.737242438755771
# Agent 64 stepping with knowledge before decay: 6.637242438755771
# Agent 64 knowledge after decay: 6.627242438755771
# Agent 64 exchanged info with social partner 62
# Agent 64 interacted with AI. Current knowledge: 8.164332334344092
# Agent 65 stepping with knowledge before decay: 6.671856582199543
# Agent 65 knowledge after decay: 6.661856582199543
# Agent 65 exchanged info with social partner 64
# Agent 65 interacted with AI. Current knowledge: 9.799549510477657
# Agent 66 stepping with knowledge before decay: 8.96187316387811
# Agent 66 knowledge after decay: 8.95187316387811
# Agent 66 exchanged info with social partner 68
# Agent 66 interacted with AI. Current knowledge: 9.609539887975373
# Agent 67 stepping with knowledge before decay: 7.509539887975373
# Agent 67 knowledge after decay: 7.499539887975374
# Agent 67 exchanged info with social partner 69
# Agent 67 interacted with AI. Current knowledge: 8.702260801250047
# Agent 68 stepping with knowledge before decay: 6.602260801250047
# Agent 68 knowledge after decay: 6.592260801250047
# Agent 68 exchanged info with social partner 69
# Agent 68 interacted with AI. Current knowledge: 8.692260801250047
# Agent 69 stepping with knowledge before decay: 4.795938356737908
# Agent 69 knowledge after decay: 4.785938356737908
# Agent 69 exchanged info with social partner 71
# Agent 69 interacted with AI. Current knowledge: 6.485501359615328
# Agent 70 stepping with knowledge before decay: 6.065501359615328
# Agent 70 knowledge after decay: 6.055501359615328
# Agent 70 exchanged info with social partner 69
# Agent 70 interacted with AI. Current knowledge: 9.473881080432687
# Agent 71 stepping with knowledge before decay: 8.729337550535124
# Agent 71 knowledge after decay: 8.719337550535124
# Agent 71 exchanged info with social partner 69
# Agent 71 interacted with AI. Current knowledge: 10.146609315483905
# Agent 72 stepping with knowledge before decay: 5.205938356737908
# Agent 72 knowledge after decay: 5.1959383567379085
# Agent 72 exchanged info with social partner 74
# Agent 72 interacted with AI. Current knowledge: 8.849380954330687
# Agent 73 stepping with knowledge before decay: 6.749380954330687
# Agent 73 knowledge after decay: 6.739380954330687
# Agent 73 exchanged info with social partner 71
# Agent 73 interacted with AI. Current knowledge: 10.206631017381687
# Agent 74 stepping with knowledge before decay: 7.499277207803197
# Agent 74 knowledge after decay: 7.489277207803197
# Agent 74 exchanged info with social partner 73
# Agent 74 interacted with AI. Current knowledge: 10.269329081066942
# Agent 75 stepping with knowledge before decay: 7.25556496995101
# Agent 75 knowledge after decay: 7.24556496995101
# Agent 75 exchanged info with social partner 77
# Agent 75 interacted with AI. Current knowledge: 10.433996998328649
# Agent 76 stepping with knowledge before decay: 8.333996998328649
# Agent 76 knowledge after decay: 8.32399699832865
# Agent 76 exchanged info with social partner 74
# Agent 76 interacted with AI. Current knowledge: 11.365314007855167
# Agent 77 stepping with knowledge before decay: 4.182840562676548
# Agent 77 knowledge after decay: 4.172840562676548
# Agent 77 exchanged info with social partner 5
# Agent 77 interacted with AI. Current knowledge: 7.146276653006546
# Agent 78 stepping with knowledge before decay: 7.503576317520201
# Agent 78 knowledge after decay: 7.493576317520201
# Agent 78 exchanged info with social partner 76
# Agent 78 interacted with AI. Current knowledge: 11.063786657924425
# Agent 79 stepping with knowledge before decay: 6.288567070214502
# Agent 79 knowledge after decay: 6.278567070214502
# Agent 79 exchanged info with social partner 81
# Agent 79 interacted with AI. Current knowledge: 7.435295739412911
# Agent 80 stepping with knowledge before decay: 5.335295739412912
# Agent 80 knowledge after decay: 5.325295739412912
# Agent 80 exchanged info with social partner 79
# Agent 80 interacted with AI. Current knowledge: 10.294541198668668
# Agent 81 stepping with knowledge before decay: 6.242943372503769
# Agent 81 knowledge after decay: 6.232943372503769
# Agent 81 exchanged info with social partner 82
# Agent 81 interacted with AI. Current knowledge: 8.332943372503768
# Agent 82 stepping with knowledge before decay: 6.6889616259358275
# Agent 82 knowledge after decay: 6.678961625935828
# Agent 82 exchanged info with social partner 81
# Agent 82 interacted with AI. Current knowledge: 10.586751412302247
# Agent 83 stepping with knowledge before decay: 4.802024408611322
# Agent 83 knowledge after decay: 4.792024408611322
# Agent 83 exchanged info with social partner 85
# Agent 83 interacted with AI. Current knowledge: 6.296823398551826
# Agent 84 stepping with knowledge before decay: 5.876823398551826
# Agent 84 knowledge after decay: 5.866823398551826
# Agent 84 exchanged info with social partner 85
# Agent 84 interacted with AI. Current knowledge: 7.966823398551826
# Agent 85 stepping with knowledge before decay: 8.874363547340044
# Agent 85 knowledge after decay: 8.864363547340044
# Agent 85 exchanged info with social partner 19
# Agent 85 interacted with AI. Current knowledge: 11.049518088504042
# Agent 86 stepping with knowledge before decay: 9.01162238849233
# Agent 86 knowledge after decay: 9.001622388492331
# Agent 86 exchanged info with social partner 85
# Agent 86 interacted with AI. Current knowledge: 10.584222893522078
# Agent 87 stepping with knowledge before decay: 5.965914561392414
# Agent 87 knowledge after decay: 5.955914561392414
# Agent 87 exchanged info with social partner 61
# Agent 87 interacted with AI. Current knowledge: 9.690630356412237
# Agent 88 stepping with knowledge before decay: 5.802422006786504
# Agent 88 knowledge after decay: 5.792422006786504
# Agent 88 exchanged info with social partner 86
# Agent 88 interacted with AI. Current knowledge: 10.520970047645273
# Agent 89 stepping with knowledge before decay: 6.7423670373278055
# Agent 89 knowledge after decay: 6.732367037327806
# Agent 89 exchanged info with social partner 90
# Agent 89 interacted with AI. Current knowledge: 8.832367037327806
# Agent 90 stepping with knowledge before decay: 6.212422006786504
# Agent 90 knowledge after decay: 6.202422006786504
# Agent 90 exchanged info with social partner 88
# Agent 90 interacted with AI. Current knowledge: 10.04652618159937
# Agent 91 stepping with knowledge before decay: 8.128827399842729
# Agent 91 knowledge after decay: 8.11882739984273
# Agent 91 exchanged info with social partner 89
# Agent 91 interacted with AI. Current knowledge: 11.419898723744
# Agent 92 stepping with knowledge before decay: 8.303237869342972
# Agent 92 knowledge after decay: 8.293237869342972
# Agent 92 exchanged info with social partner 94
# Agent 92 interacted with AI. Current knowledge: 10.254576215367694
# Agent 93 stepping with knowledge before decay: 8.154576215367694
# Agent 93 knowledge after decay: 8.144576215367694
# Agent 93 exchanged info with social partner 95
# Agent 93 interacted with AI. Current knowledge: 10.630257255308786
# Agent 94 stepping with knowledge before decay: 8.530257255308786
# Agent 94 knowledge after decay: 8.520257255308787
# Agent 94 exchanged info with social partner 96
# Agent 94 interacted with AI. Current knowledge: 10.62931036546395
# Agent 95 stepping with knowledge before decay: 8.52931036546395
# Agent 95 knowledge after decay: 8.51931036546395
# Agent 95 exchanged info with social partner 93
# Agent 95 interacted with AI. Current knowledge: 11.486943290415821
# Agent 96 stepping with knowledge before decay: 7.086704022507561
# Agent 96 knowledge after decay: 7.0767040225075615
# Agent 96 exchanged info with social partner 94
# Agent 96 interacted with AI. Current knowledge: 10.953480638908173
# Agent 97 stepping with knowledge before decay: 9.563363475619111
# Agent 97 knowledge after decay: 9.553363475619111
# Agent 97 exchanged info with social partner 99
# Agent 97 interacted with AI. Current knowledge: 8.910043178591394
# Agent 98 stepping with knowledge before decay: 6.810043178591394
# Agent 98 knowledge after decay: 6.800043178591395
# Agent 98 exchanged info with social partner 97
# Agent 98 interacted with AI. Current knowledge: 9.296761908749785
# Agent 99 stepping with knowledge before decay: 5.433965597420173
# Agent 99 knowledge after decay: 5.423965597420173
# Agent 99 exchanged info with social partner 100
# Agent 99 interacted with AI. Current knowledge: 7.5239655974201725
# Agent 0 stepping with knowledge before decay: 7.204867046060288
# Agent 0 knowledge after decay: 7.194867046060288
# Agent 0 exchanged info with social partner 1
# Agent 0 exchanged info with org partner 2
# Agent 0 interacted with AI. Current knowledge: 10.839913139479108
# Agent 1 stepping with knowledge before decay: 8.68991313947911
# Agent 1 knowledge after decay: 8.67991313947911
# Agent 1 exchanged info with social partner 3
# Agent 1 exchanged info with org partner 8
# Agent 1 interacted with AI. Current knowledge: 11.024312103930669
# Agent 2 stepping with knowledge before decay: 8.111965532625725
# ...
# Agent 30 knowledge after decay: 448.44649406307616
# Agent 30 exchanged info with social partner 34
# Agent 30 interacted with AI. Current knowledge: 456.8571408309332
# Agent 31 stepping with knowledge before decay: 444.6864161704772
# Agent 31 knowledge after decay: 444.6764161704772
# Agent 31 exchanged info with social partner 95
# Agent 31 interacted with AI. Current knowledge: 453.8552112005415
# Agent 32 stepping with knowledge before decay: 454.112136735708
# Agent 32 knowledge after decay: 454.10213673570803
# Agent 32 exchanged info with social partner 33
# Agent 32 interacted with AI. Current knowledge: 461.10213673570803
# Agent 33 stepping with knowledge before decay: 449.8571408309332
# Agent 33 knowledge after decay: 449.8471408309332
# Agent 33 exchanged info with social partner 35
# Agent 33 interacted with AI. Current knowledge: 455.3081565103086
# Agent 34 stepping with knowledge before decay: 448.3081565103086
# Agent 34 knowledge after decay: 448.2981565103086
# Agent 34 exchanged info with social partner 30
# Agent 34 interacted with AI. Current knowledge: 456.99228634039287
# Agent 35 stepping with knowledge before decay: 450.2738300735077
# Agent 35 knowledge after decay: 450.26383007350773
# Agent 35 exchanged info with social partner 34
# Agent 35 interacted with AI. Current knowledge: 459.7859932919082
# Agent 36 stepping with knowledge before decay: 446.0327103754254
# Agent 36 knowledge after decay: 446.0227103754254
# Agent 36 exchanged info with social partner 37
# Agent 36 interacted with AI. Current knowledge: 453.0227103754254
# Agent 37 stepping with knowledge before decay: 451.5865461153758
# Agent 37 knowledge after decay: 451.57654611537583
# Agent 37 exchanged info with social partner 74
# Agent 37 interacted with AI. Current knowledge: 458.34850807632165
# Agent 38 stepping with knowledge before decay: 444.6034192483611
# Agent 38 knowledge after decay: 444.5934192483611
# Agent 38 exchanged info with social partner 31
# Agent 38 interacted with AI. Current knowledge: 457.72528003964715
# Agent 39 stepping with knowledge before decay: 452.2885949177443
# Agent 39 knowledge after decay: 452.27859491774433
# Agent 39 exchanged info with social partner 37
# Agent 39 interacted with AI. Current knowledge: 459.65065264658483
# Agent 40 stepping with knowledge before decay: 449.58506732143377
# Agent 40 knowledge after decay: 449.5750673214338
# Agent 40 exchanged info with social partner 38
# Agent 40 interacted with AI. Current knowledge: 460.96178769887774
# Agent 41 stepping with knowledge before decay: 449.64993979979147
# Agent 41 knowledge after decay: 449.6399397997915
# Agent 41 exchanged info with social partner 57
# Agent 41 interacted with AI. Current knowledge: 456.99466171356187
# Agent 42 stepping with knowledge before decay: 448.32334214832923
# Agent 42 knowledge after decay: 448.31334214832924
# Agent 42 exchanged info with social partner 28
# Agent 42 interacted with AI. Current knowledge: 458.53490124977554
# Agent 43 stepping with knowledge before decay: 445.45972390796555
# Agent 43 knowledge after decay: 445.44972390796556
# Agent 43 exchanged info with social partner 42
# Agent 43 interacted with AI. Current knowledge: 458.2221928107637
# Agent 44 stepping with knowledge before decay: 443.962643555684
# Agent 44 knowledge after decay: 443.952643555684
# Agent 44 exchanged info with social partner 69
# Agent 44 interacted with AI. Current knowledge: 453.54997577203653
# Agent 45 stepping with knowledge before decay: 449.720131997518
# Agent 45 knowledge after decay: 449.71013199751803
# Agent 45 exchanged info with social partner 47
# Agent 45 interacted with AI. Current knowledge: 454.30157934149184
# Agent 46 stepping with knowledge before decay: 447.30157934149184
# Agent 46 knowledge after decay: 447.29157934149185
# Agent 46 exchanged info with social partner 19
# Agent 46 interacted with AI. Current knowledge: 455.85649564821335
# Agent 47 stepping with knowledge before decay: 450.912643555684
# Agent 47 knowledge after decay: 450.902643555684
# Agent 47 exchanged info with social partner 29
# Agent 47 interacted with AI. Current knowledge: 460.77629167773773
# Agent 48 stepping with knowledge before decay: 446.56339235078576
# Agent 48 knowledge after decay: 446.55339235078577
# Agent 48 exchanged info with social partner 17
# Agent 48 interacted with AI. Current knowledge: 458.0271138485323
# Agent 49 stepping with knowledge before decay: 445.9847447172874
# Agent 49 knowledge after decay: 445.9747447172874
# Agent 49 exchanged info with social partner 48
# Agent 49 interacted with AI. Current knowledge: 460.3755181975126
# Agent 50 stepping with knowledge before decay: 446.1972112734088
# Agent 50 knowledge after decay: 446.1872112734088
# Agent 50 exchanged info with social partner 49
# Agent 50 interacted with AI. Current knowledge: 459.10716256097055
# Agent 51 stepping with knowledge before decay: 456.2842186111655
# Agent 51 knowledge after decay: 456.2742186111655
# Agent 51 exchanged info with social partner 93
# Agent 51 interacted with AI. Current knowledge: 461.8564737011596
# Agent 52 stepping with knowledge before decay: 453.1472112734088
# Agent 52 knowledge after decay: 453.1372112734088
# Agent 52 exchanged info with social partner 8
# Agent 52 interacted with AI. Current knowledge: 460.97052828389906
# Agent 53 stepping with knowledge before decay: 452.0233624429279
# Agent 53 knowledge after decay: 452.0133624429279
# Agent 53 exchanged info with social partner 82
# Agent 53 interacted with AI. Current knowledge: 458.9281945641968
# Agent 54 stepping with knowledge before decay: 449.91405990927444
# Agent 54 knowledge after decay: 449.90405990927445
# Agent 54 exchanged info with social partner 8
# Agent 54 interacted with AI. Current knowledge: 458.93729409658675
# Agent 55 stepping with knowledge before decay: 443.21167463265806
# Agent 55 knowledge after decay: 443.20167463265807
# Agent 55 exchanged info with social partner 27
# Agent 55 interacted with AI. Current knowledge: 455.56784631599373
# Agent 56 stepping with knowledge before decay: 449.99466171356187
# Agent 56 knowledge after decay: 449.9846617135619
# Agent 56 exchanged info with social partner 55
# Agent 56 interacted with AI. Current knowledge: 461.4609779050743
# Agent 57 stepping with knowledge before decay: 447.51569025840183
# Agent 57 knowledge after decay: 447.50569025840184
# Agent 57 exchanged info with social partner 56
# Agent 57 interacted with AI. Current knowledge: 458.5367682871978
# Agent 58 stepping with knowledge before decay: 453.04958179747
# Agent 58 knowledge after decay: 453.03958179747
# Agent 58 exchanged info with social partner 57
# Agent 58 interacted with AI. Current knowledge: 464.2502798512721
# Agent 59 stepping with knowledge before decay: 453.81771037129204
# Agent 59 knowledge after decay: 453.80771037129205
# Agent 59 exchanged info with social partner 57
# Agent 59 interacted with AI. Current knowledge: 462.5289951112821
# Agent 60 stepping with knowledge before decay: 453.95875536216255
# Agent 60 knowledge after decay: 453.94875536216256
# Agent 60 exchanged info with social partner 55
# Agent 60 interacted with AI. Current knowledge: 461.2048666336184
# Agent 61 stepping with knowledge before decay: 454.4656902584018
# Agent 61 knowledge after decay: 454.45569025840183
# Agent 61 exchanged info with social partner 58
# Agent 61 interacted with AI. Current knowledge: 463.49622927279984
# Agent 62 stepping with knowledge before decay: 448.36256206135414
# Agent 62 knowledge after decay: 448.35256206135415
# Agent 62 exchanged info with social partner 63
# Agent 62 interacted with AI. Current knowledge: 455.35256206135415
# Agent 63 stepping with knowledge before decay: 446.1888841536967
# Agent 63 knowledge after decay: 446.1788841536967
# Agent 63 exchanged info with social partner 61
# Agent 63 interacted with AI. Current knowledge: 460.69187539365754
# Agent 64 stepping with knowledge before decay: 449.0020275372365
# Agent 64 knowledge after decay: 448.9920275372365
# Agent 64 exchanged info with social partner 63
# Agent 64 interacted with AI. Current knowledge: 459.1722947992953
# Agent 65 stepping with knowledge before decay: 453.6384529190004
# Agent 65 knowledge after decay: 453.6284529190004
# Agent 65 exchanged info with social partner 25
# Agent 65 interacted with AI. Current knowledge: 461.073460315464
# Agent 66 stepping with knowledge before decay: 450.9655602422555
# Agent 66 knowledge after decay: 450.9555602422555
# Agent 66 exchanged info with social partner 86
# Agent 66 interacted with AI. Current knowledge: 460.4818903560323
# Agent 67 stepping with knowledge before decay: 448.5008353462788
# Agent 67 knowledge after decay: 448.4908353462788
# Agent 67 exchanged info with social partner 65
# Agent 67 interacted with AI. Current knowledge: 460.83156507278704
# Agent 68 stepping with knowledge before decay: 446.54997577203653
# Agent 68 knowledge after decay: 446.53997577203654
# Agent 68 exchanged info with social partner 74
# Agent 68 interacted with AI. Current knowledge: 455.9442419241791
# Agent 69 stepping with knowledge before decay: 453.719172189684
# Agent 69 knowledge after decay: 453.709172189684
# Agent 69 exchanged info with social partner 99
# Agent 69 interacted with AI. Current knowledge: 462.2336986783264
# Agent 70 stepping with knowledge before decay: 449.150503732234
# Agent 70 knowledge after decay: 449.140503732234
# Agent 70 exchanged info with social partner 71
# Agent 70 interacted with AI. Current knowledge: 456.140503732234
# Agent 71 stepping with knowledge before decay: 447.18795091393974
# Agent 71 knowledge after decay: 447.17795091393975
# Agent 71 exchanged info with social partner 95
# Agent 71 interacted with AI. Current knowledge: 454.0165810572406
# Agent 72 stepping with knowledge before decay: 448.42004758986775
# Agent 72 knowledge after decay: 448.41004758986776
# Agent 72 exchanged info with social partner 74
# Agent 72 interacted with AI. Current knowledge: 455.6771447570234
# Agent 73 stepping with knowledge before decay: 448.6771447570234
# Agent 73 knowledge after decay: 448.66714475702344
# Agent 73 exchanged info with social partner 74
# Agent 73 interacted with AI. Current knowledge: 455.66714475702344
# Agent 74 stepping with knowledge before decay: 445.6804888806979
# Agent 74 knowledge after decay: 445.6704888806979
# Agent 74 exchanged info with social partner 9
# Agent 74 interacted with AI. Current knowledge: 458.4721594771028
# Agent 75 stepping with knowledge before decay: 445.42814917123866
# Agent 75 knowledge after decay: 445.41814917123867
# Agent 75 exchanged info with social partner 76
# Agent 75 interacted with AI. Current knowledge: 452.41814917123867
# Agent 76 stepping with knowledge before decay: 454.4011083101355
# Agent 76 knowledge after decay: 454.3911083101355
# Agent 76 exchanged info with social partner 78
# Agent 76 interacted with AI. Current knowledge: 457.3023320845058
# Agent 77 stepping with knowledge before decay: 450.3023320845058
# Agent 77 knowledge after decay: 450.2923320845058
# Agent 77 exchanged info with social partner 76
# Agent 77 interacted with AI. Current knowledge: 458.35524062787226
# Agent 78 stepping with knowledge before decay: 446.20355585887614
# Agent 78 knowledge after decay: 446.19355585887615
# Agent 78 exchanged info with social partner 21
# Agent 78 interacted with AI. Current knowledge: 457.8971000438679
# Agent 79 stepping with knowledge before decay: 448.52368848876233
# Agent 79 knowledge after decay: 448.51368848876234
# Agent 79 exchanged info with social partner 77
# Agent 79 interacted with AI. Current knowledge: 459.90801028663407
# Agent 80 stepping with knowledge before decay: 450.94137089960543
# Agent 80 knowledge after decay: 450.93137089960544
# Agent 80 exchanged info with social partner 81
# Agent 80 interacted with AI. Current knowledge: 457.93137089960544
# Agent 81 stepping with knowledge before decay: 451.9281945641968
# Agent 81 knowledge after decay: 451.9181945641968
# Agent 81 exchanged info with social partner 79
# Agent 81 interacted with AI. Current knowledge: 461.90764730403237
# Agent 82 stepping with knowledge before decay: 448.6006442288597
# Agent 82 knowledge after decay: 448.59064422885973
# Agent 82 exchanged info with social partner 65
# Agent 82 interacted with AI. Current knowledge: 458.21110465082336
# Agent 83 stepping with knowledge before decay: 447.0607914563685
# Agent 83 knowledge after decay: 447.05079145636853
# Agent 83 exchanged info with social partner 85
# Agent 83 interacted with AI. Current knowledge: 458.93828195989647
# Agent 84 stepping with knowledge before decay: 451.93828195989647
# Agent 84 knowledge after decay: 451.9282819598965
# Agent 84 exchanged info with social partner 83
# Agent 84 interacted with AI. Current knowledge: 462.0696933053599
# Agent 85 stepping with knowledge before decay: 453.4818903560323
# Agent 85 knowledge after decay: 453.4718903560323
# Agent 85 exchanged info with social partner 66
# Agent 85 interacted with AI. Current knowledge: 464.27267533574815
# Agent 86 stepping with knowledge before decay: 454.0107914563685
# Agent 86 knowledge after decay: 454.0007914563685
# Agent 86 exchanged info with social partner 84
# Agent 86 interacted with AI. Current knowledge: 463.4695367081325
# Agent 87 stepping with knowledge before decay: 446.9340179993294
# Agent 87 knowledge after decay: 446.9240179993294
# Agent 87 exchanged info with social partner 19
# Agent 87 interacted with AI. Current knowledge: 454.8902568237714
# Agent 88 stepping with knowledge before decay: 448.60102369596956
# Agent 88 knowledge after decay: 448.59102369596957
# Agent 88 exchanged info with social partner 79
# Agent 88 interacted with AI. Current knowledge: 458.74933550000094
# Agent 89 stepping with knowledge before decay: 446.4887287911537
# Agent 89 knowledge after decay: 446.4787287911537
# Agent 89 exchanged info with social partner 88
# Agent 89 interacted with AI. Current knowledge: 457.68449280746256
# Agent 90 stepping with knowledge before decay: 449.5982242181537
# Agent 90 knowledge after decay: 449.5882242181537
# Agent 90 exchanged info with social partner 88
# Agent 90 interacted with AI. Current knowledge: 457.1363585128081
# Agent 91 stepping with knowledge before decay: 458.0500565688194
# Agent 91 knowledge after decay: 458.0400565688194
# Agent 91 exchanged info with social partner 90
# Agent 91 interacted with AI. Current knowledge: 464.862274688141
# Agent 92 stepping with knowledge before decay: 454.8564737011596
# Agent 92 knowledge after decay: 454.8464737011596
# Agent 92 exchanged info with social partner 93
# Agent 92 interacted with AI. Current knowledge: 461.8464737011596
# Agent 93 stepping with knowledge before decay: 449.0440062306057
# Agent 93 knowledge after decay: 449.0340062306057
# Agent 93 exchanged info with social partner 95
# Agent 93 interacted with AI. Current knowledge: 455.0252936439232
# Agent 94 stepping with knowledge before decay: 448.0252936439232
# Agent 94 knowledge after decay: 448.0152936439232
# Agent 94 exchanged info with social partner 95
# Agent 94 interacted with AI. Current knowledge: 455.0152936439232
# Agent 95 stepping with knowledge before decay: 451.84116558384494
# Agent 95 knowledge after decay: 451.83116558384495
# Agent 95 exchanged info with social partner 45
# Agent 95 interacted with AI. Current knowledge: 459.69057067794074
# Agent 96 stepping with knowledge before decay: 452.17002630121226
# Agent 96 knowledge after decay: 452.16002630121227
# Agent 96 exchanged info with social partner 94
# Agent 96 interacted with AI. Current knowledge: 460.59265997256773
# Agent 97 stepping with knowledge before decay: 458.79116558384493
# Agent 97 knowledge after decay: 458.78116558384494
# Agent 97 exchanged info with social partner 99
# Agent 97 interacted with AI. Current knowledge: 464.0074321310857
# Agent 98 stepping with knowledge before decay: 457.0074321310857
# Agent 98 knowledge after decay: 456.9974321310857
# Agent 98 exchanged info with social partner 48
# Agent 98 interacted with AI. Current knowledge: 462.18647516429917
# Agent 99 stepping with knowledge before decay: 450.8465732424211
# Agent 99 knowledge after decay: 450.8365732424211
# Agent 99 exchanged info with social partner 32
# Agent 99 interacted with AI. Current knowledge: 459.3458922214813

# %%
def save_data(self):
        """
        Save collected data to CSV files.
        """
        data = self.datacollector.get_model_vars_dataframe()
        data.to_csv(os.path.join(self.output_dir, 'model_data.csv'), index=True)

        # Optionally, save final network states
        # Save social network
        nx.write_gexf(self.social_network, os.path.join(self.output_dir, 'social_network.gexf'))
        # Save organizational network
        nx.write_gexf(self.org_network, os.path.join(self.output_dir, 'organizational_network.gexf'))

        print(f"Simulation data saved to {self.output_dir}")

# ==========================
